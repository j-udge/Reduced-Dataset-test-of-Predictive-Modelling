# %%
import pandas as pd
import numpy as np
import os
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_100_42=pd.read_csv(r"C:\PredictiveModelling\Code\100_ofat_model_results.csv")
df_95_42=pd.read_csv(r"C:/PredictiveModelling/Code/95_ofat_model_results.csv")
df_90_42=pd.read_csv(r"C:/PredictiveModelling/Code/90_ofat_model_results.csv")
df_85_42=pd.read_csv(r"C:/PredictiveModelling/Code/85_ofat_model_results.csv")
df_80_42=pd.read_csv(r"C:/PredictiveModelling/Code/80_ofat_model_results.csv")
df_100_0=pd.read_csv(r"Data\1000_ofat_model_results.csv")
df_95_0=pd.read_csv(r"C:\PredictiveModelling\Data\950_ofat_model_results.csv")
df_90_0=pd.read_csv(r"C:\PredictiveModelling\Data\900_ofat_model_results.csv")
df_85_0=pd.read_csv(r"C:\PredictiveModelling\Data\850_ofat_model_results.csv")
df_80_0=pd.read_csv(r"C:\PredictiveModelling\Data\800_ofat_model_results.csv")
df_100_77=pd.read_csv(r"C:\PredictiveModelling\Data\10077_ofat_model_results.csv")
df_95_77=pd.read_csv(r"C:\PredictiveModelling\Data\9577_ofat_model_results.csv")
df_90_77=pd.read_csv(r"C:\PredictiveModelling\Data\9077_ofat_model_results.csv")
df_85_77=pd.read_csv(r"C:\PredictiveModelling\Data\8577_ofat_model_results.csv")
df_80_77=pd.read_csv(r"C:\PredictiveModelling\Data\8077_ofat_model_results.csv")
df_100_99=pd.read_csv(r"C:\PredictiveModelling\Data\10099_ofat_model_results.csv")
df_95_99=pd.read_csv(r"C:\PredictiveModelling\Data\9599_ofat_model_results.csv")
df_90_99=pd.read_csv(r"C:\PredictiveModelling\Data\9099_ofat_model_results.csv")
df_85_99=pd.read_csv(r"C:\PredictiveModelling\Data\8599_ofat_model_results.csv")
df_80_99=pd.read_csv(r"C:\PredictiveModelling\Data\8099_ofat_model_results.csv")
df_100_32=pd.read_csv(r"C:\PredictiveModelling\Data\10032_ofat_model_results.csv")
df_95_32=pd.read_csv(r"C:\PredictiveModelling\Data\9532_ofat_model_results.csv")
df_90_32=pd.read_csv(r"C:\PredictiveModelling\Data\9032_ofat_model_results.csv")
df_85_32=pd.read_csv(r"C:\PredictiveModelling\Data\8532_ofat_model_results.csv")
df_80_32=pd.read_csv(r"C:\PredictiveModelling\Data\8032_ofat_model_results.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_100_42=pd.read_csv(r"C:\PredictiveModelling\Code\100_ofat_model_results.csv")
#       2 df_95_42=pd.read_csv(r"C:/PredictiveModelling/Code/95_ofat_model_results.csv")
#       3 df_90_42=pd.read_csv(r"C:/PredictiveModelling/Code/90_ofat_model_results.csv")
#
# NameError: name 'pd' is not defined

# %%
df_100.columns = pd.MultiIndex.from_product([
    ['100 percent'],          
    df_100.columns            
])


df_95.columns = pd.MultiIndex.from_product([
    ['0.95 Split'],          
    df_95.columns            
])


df_90.columns = pd.MultiIndex.from_product([
    ['0.90 Split'],          
    df_90.columns           
])

df_85.columns = pd.MultiIndex.from_product([
    ['0.85 Split'],          
    df_85.columns            
])


df_80.columns = pd.MultiIndex.from_product([
    ['0.80 Split'],          
    df_80.columns            
])

# %%
combined_df = pd.concat([df_100, df_95, df_90, df_85, df_80], axis=1)

# %%
combined_df.head()
# Out:
#       100 percent                                                            \
#   Target Variable    Parameter Tested       Value 5-Fold CV Neg MSE Test R2
# 0             EE%  hidden_layer_sizes    (50, 25)          -35.6906  0.8087
# 1             EE%  hidden_layer_sizes   (100, 50)          -26.6775  0.8419
# 2             EE%  hidden_layer_sizes   (150, 75)          -30.6442  0.8254
# 3             EE%  hidden_layer_sizes  (100, 100)          -29.3609  0.8678
# 4             EE%  hidden_layer_sizes  (200, 100)          -26.8019  0.8031
#
#                                   0.95 Split                                  \
#   Test MSE Iterations Needed Target Variable    Parameter Tested       Value
# 0  20.7164              3622             EE%  hidden_layer_sizes    (50, 25)
# 1  17.1241              2103             EE%  hidden_layer_sizes   (100, 50)
# 2  18.9085              1732             EE%  hidden_layer_sizes   (150, 75)
# ...

# %%
file_name="Combined_Dataframe_with_splits.xlsx"
folder_name="Data"

# %%
os.makedirs(folder_name, exist_ok=True)

# %%
file_path=os.path.join(folder_name, file_name)
combined_df.to_excel(file_path)
